# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Input
from tensorflow.keras.utils import to_categorical
# Out:
# 2025-01-25 14:06:06.469823: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
df = pd.read_csv("Data/mnist_train.csv")

# %%
import tensorflow as tf

# %%
a = tf.constant(5)
b = tf.constant(3)

# %%
c = tf.add(a,b)
d = tf.multiply(a,b)

# %%
print(f"a: {a}, b: {b}")
print(f"Addition (c): {c}")
print(f"Multiplication (d): {d}")
# Out:
# a: 5, b: 3
# Addition (c): 8
# Multiplication (d): 15

# %%
x = tf.Variable(10.0)

# %%
x.assign(20.0)
# Out:
# <tf.Variable 'UnreadVariable' shape=() dtype=float32, numpy=20.0>

# %%
x.assign(20.0)
print(f"Updated x: {x}")
# Out:
# Updated x: <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=20.0>

# %%
x.assign_add(30.0)

print(f"Updated x: {x}")
# Out:
# Updated x: <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=50.0>

# %% [markdown]
# Exercise:
#
# Create a variable initialized to 100 and decrement it by 15. \
# Create a 2D variable with shape [2, 3] filled with zeros, and update its values.

# %%
x = tf.Variable(100.0)
x.assign_sub(15.0)

print(f"decreamented: {x}")

# %%
y = tf.Variable(tf.zeros([2,3]))
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=float32, numpy=
# array([[0., 0., 0.],
#        [0., 0., 0.]], dtype=float32)>

# %%
y.assign_add(tf.ones([2,3]))
# Out:
# <tf.Variable 'UnreadVariable' shape=(2, 3) dtype=float32, numpy=
# array([[1., 1., 1.],
#        [1., 1., 1.]], dtype=float32)>

# %%
y[0,1].assign(10.0)
# Out:
# <tf.Variable 'UnreadVariable' shape=(2, 3) dtype=float32, numpy=
# array([[ 1., 10.,  1.],
#        [ 1.,  1.,  1.]], dtype=float32)>

# %% [markdown]
# # Step 3: Basic Machine Learning Workflow

# %%
X = np.array([[1.0], [2.0], [3.0], [4.0]])
y = np.array([[2.0], [4.0], [6.0], [8.0]])

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units = 1, input_shape = [1])
])

# %%
model.compile(optimizer = "sgd", loss='mean_squared_error')
model.fit(X,y, epochs = 500, verbose = 0 )

# %%
print(f" prediction for 5: {model.predict(np.array([[5.0]]))}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  prediction for 5: [[9.959146]]
